# %%
import mlflow
# Connect to Databricks workspace with submitted credentials or use stored credentials
mlflow.login()
# Set tracking URI to Databricks -  tell MLflow to send the data into Databricks Workspace
mlflow.set_tracking_uri("databricks")
# Out:
# 2025/10/22 01:23:04 INFO mlflow.utils.credentials: Successfully connected to MLflow hosted tracking server! Host: https://dbc-7d1169bb-4536.cloud.databricks.com.

# %%
import os;
from datetime import datetime
from dotenv import load_dotenv

#Do not use .env file in shared databricks environment
#https://medium.com/@generative_ai/environment-variables-setting-in-databricks-dde16e3c3888 
load_dotenv()

experiment_name = f"/Users/{os.environ['USER_EMAIL']}/test-experiment"
try:
    mlflow.create_experiment(experiment_name)
except mlflow.exceptions.MlflowException:
    print(f"Experiment {experiment_name} already exists.")

mlflow.set_experiment(experiment_name)


with mlflow.start_run(run_name=f'run-{datetime.now()}') as run:
    mlflow.log_param("param1", 5)
    mlflow.log_metric("metric1", 0.85)
# Out:
# Experiment /Users/marijo.maracic@gmail.com/test-experiment already exists.
# 🏃 View run run-2025-10-22 01:26:20.756403 at: https://dbc-7d1169bb-4536.cloud.databricks.com/ml/experiments/3044475861801323/runs/2978f0bd71824bc3bd8cf4306874deeb
# 🧪 View experiment at: https://dbc-7d1169bb-4536.cloud.databricks.com/ml/experiments/3044475861801323
# 🏃 View run run-2025-10-22 01:26:20.756403 at: https://dbc-7d1169bb-4536.cloud.databricks.com/ml/experiments/3044475861801323/runs/2978f0bd71824bc3bd8cf4306874deeb
# 🧪 View experiment at: https://dbc-7d1169bb-4536.cloud.databricks.com/ml/experiments/3044475861801323

# %%
import pandas as pd
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#          Date  store  product  number_sold
# 0  2010-01-01      0        0          801
# 1  2010-01-02      0        0          810
# 2  2010-01-03      0        0          818
# 3  2010-01-04      0        0          796
# 4  2010-01-05      0        0          808

# %%
# Count unique combinations of store and product
unique_combinations = df[['store','product']].drop_duplicates().shape[0]
print(f"Number of unique (store, product) combinations: {unique_combinations}")

# Count rows per (store, product) combination, sort descending
counts = df.groupby(['store', 'product']).size().reset_index(name='count')
counts_sorted = counts.sort_values('count', ascending=False)
display(counts_sorted)

# Show min and max counts
min_count = counts_sorted['count'].min()
max_count = counts_sorted['count'].max()
print(f"Min rows per (store, product): {min_count}")
print(f"Max rows per (store, product): {max_count}")
# Out:
# Number of unique (store, product) combinations: 70
#     store  product  count
# 0       0        0   3287
# 1       0        1   3287
# 2       0        2   3287
# 3       0        3   3287
# 4       0        4   3287
# ..    ...      ...    ...
# 65      6        5   3287
# 66      6        6   3287
# 67      6        7   3287
# 68      6        8   3287
# 69      6        9   3287
#
# [70 rows x 3 columns]
# Min rows per (store, product): 3287
# Max rows per (store, product): 3287

# %%
# Show minimum and maximum date in the dataset
print('Min date:', df['Date'].min())
print('Max date:', df['Date'].max())
# Out:
# Min date: 2010-01-01
# Max date: 2018-12-31

# %%
from statsmodels.tsa.arima.model import ARIMA
from tqdm import tqdm

results = {}
models = {}
groups = list(df.groupby(['store', 'product']))
for (store, product), group in tqdm(groups, desc='Training ARIMA models'):
    group_sorted = group.sort_values('Date')
    group_sorted = group_sorted.set_index('Date')
    try:
        model = ARIMA(group_sorted['number_sold'], order=(1,1,1))
        fit = model.fit()
        models[(store, product)] = fit
        forecast = fit.forecast(steps=1)[0]
        results[(store, product)] = forecast
    except Exception as e:
        models[(store, product)] = None
        results[(store, product)] = f'Error: {e}'

df_results = pd.DataFrame([
    {'store': k[0], 'product': k[1], 'forecast': v} for k, v in results.items()
])
display(df_results)
# Out:
# Training ARIMA models:   0%|          | 0/70 [00:00<?, ?it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:   1%|▏         | 1/70 [00:00<00:34,  1.99it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:   3%|▎         | 2/70 [00:01<00:37,  1.80it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:   4%|▍         | 3/70 [00:01<00:32,  2.03it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:   6%|▌         | 4/70 [00:02<00:33,  1.97it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:   7%|▋         | 5/70 [00:02<00:39,  1.64it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:   9%|▊         | 6/70 [00:03<00:35,  1.80it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  10%|█         | 7/70 [00:03<00:32,  1.97it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  11%|█▏        | 8/70 [00:04<00:28,  2.18it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  13%|█▎        | 9/70 [00:04<00:28,  2.15it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  14%|█▍        | 10/70 [00:05<00:33,  1.81it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  16%|█▌        | 11/70 [00:05<00:30,  1.92it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  17%|█▋        | 12/70 [00:06<00:39,  1.47it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  19%|█▊        | 13/70 [00:07<00:34,  1.68it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  20%|██        | 14/70 [00:07<00:30,  1.83it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  21%|██▏       | 15/70 [00:08<00:33,  1.63it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  23%|██▎       | 16/70 [00:08<00:30,  1.78it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  24%|██▍       | 17/70 [00:09<00:33,  1.59it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  26%|██▌       | 18/70 [00:10<00:31,  1.66it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  27%|██▋       | 19/70 [00:10<00:27,  1.85it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  29%|██▊       | 20/70 [00:10<00:25,  1.94it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  30%|███       | 21/70 [00:11<00:23,  2.11it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  31%|███▏      | 22/70 [00:12<00:25,  1.88it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  33%|███▎      | 23/70 [00:12<00:23,  1.98it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  34%|███▍      | 24/70 [00:12<00:22,  2.01it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  36%|███▌      | 25/70 [00:13<00:27,  1.63it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  37%|███▋      | 26/70 [00:14<00:25,  1.74it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  39%|███▊      | 27/70 [00:14<00:23,  1.84it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  40%|████      | 28/70 [00:15<00:21,  1.95it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  41%|████▏     | 29/70 [00:15<00:19,  2.10it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  43%|████▎     | 30/70 [00:16<00:18,  2.21it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  44%|████▍     | 31/70 [00:16<00:18,  2.15it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  46%|████▌     | 32/70 [00:17<00:19,  1.93it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  47%|████▋     | 33/70 [00:17<00:18,  2.03it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  49%|████▊     | 34/70 [00:18<00:17,  2.10it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  50%|█████     | 35/70 [00:18<00:20,  1.71it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  51%|█████▏    | 36/70 [00:19<00:21,  1.55it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# ...
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  83%|████████▎ | 58/70 [00:32<00:05,  2.02it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  84%|████████▍ | 59/70 [00:33<00:05,  2.13it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  86%|████████▌ | 60/70 [00:33<00:04,  2.36it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  87%|████████▋ | 61/70 [00:33<00:03,  2.36it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  89%|████████▊ | 62/70 [00:34<00:03,  2.00it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  90%|█████████ | 63/70 [00:34<00:03,  2.16it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  91%|█████████▏| 64/70 [00:35<00:02,  2.14it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  93%|█████████▎| 65/70 [00:36<00:03,  1.66it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  94%|█████████▍| 66/70 [00:36<00:02,  1.84it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  96%|█████████▌| 67/70 [00:36<00:01,  2.02it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  97%|█████████▋| 68/70 [00:37<00:00,  2.07it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models:  99%|█████████▊| 69/70 [00:37<00:00,  2.22it/s]/home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /home/marijo/.cache/pypoetry/virtualenvs/databricks-timeseries-ddx-2ipW-py3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /tmp/ipykernel_34713/361797098.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast = fit.forecast(steps=1)[0]
# Training ARIMA models: 100%|██████████| 70/70 [00:38<00:00,  1.82it/s]
#     store  product    forecast
# 0       0        0  840.743832
# 1       0        1  705.695164
# 2       0        2  973.385224
# 3       0        3  886.574732
# 4       0        4  979.197684
# ..    ...      ...         ...
# 65      6        5  898.873548
# 66      6        6  963.214415
# 67      6        7  832.240485
# 68      6        8  826.216882
# 69      6        9  905.097791
#
# [70 rows x 3 columns]

# %%
import pandas as pd
test_df = pd.read_csv('data/test.csv')
test_df.head()
# Out:
#          Date  store  product  number_sold
# 0  2019-01-01      0        0          845
# 1  2019-01-02      0        0          851
# 2  2019-01-03      0        0          840
# 3  2019-01-04      0        0          842
# 4  2019-01-05      0        0          845

# %%
# Statistics for store, product combinations in test data
unique_combinations_test = test_df[['store','product']].drop_duplicates().shape[0]
print(f"Number of unique (store, product) combinations in test data: {unique_combinations_test}")

counts_test = test_df.groupby(['store', 'product']).size().reset_index(name='count')
counts_test_sorted = counts_test.sort_values('count', ascending=False)
display(counts_test_sorted)

min_count_test = counts_test_sorted['count'].min()
max_count_test = counts_test_sorted['count'].max()
print(f"Min points per (store, product) in test: {min_count_test}")
print(f"Max points per (store, product) in test: {max_count_test}")
# Out:
# Number of unique (store, product) combinations in test data: 70
#     store  product  count
# 0       0        0    365
# 1       0        1    365
# 2       0        2    365
# 3       0        3    365
# 4       0        4    365
# ..    ...      ...    ...
# 65      6        5    365
# 66      6        6    365
# 67      6        7    365
# 68      6        8    365
# 69      6        9    365
#
# [70 rows x 3 columns]
# Min points per (store, product) in test: 365
# Max points per (store, product) in test: 365

# %%
# Generate 365 predictions for each (store, product) using trained models and compare with test data
import numpy as np
predictions = {}
for key, model in models.items():
    if model is not None:
        try:
            forecast = model.forecast(steps=365)
            predictions[key] = forecast
        except Exception as e:
            predictions[key] = f'Error: {e}'
    else:
        predictions[key] = None

# Compare predictions with test data and calculate error metrics
comparison_results = []
for (store, product), forecast in predictions.items():
    test_points = test_df[(test_df['store'] == store) & (test_df['product'] == product)].sort_values('Date')
    if isinstance(forecast, (list, pd.Series)) and len(test_points) > 0:
        actual = test_points['number_sold'].values[:365]
        pred = forecast[:len(actual)]
        mse = np.mean((actual - pred) ** 2)
        mae = np.mean(np.abs(actual - pred))
        rmse = np.sqrt(mse)
        comparison_results.append({
            'store': store,
            'product': product,
            'actual': actual,
            'predicted': pred,
            'mse': mse,
            'mae': mae,
            'rmse': rmse
        })

# Sort by descending MSE
comparison_results_sorted = sorted(comparison_results, key=lambda x: x['mse'], reverse=True)

# Show best and worst MSE value
if comparison_results_sorted:
    best = comparison_results_sorted[-1]
    worst = comparison_results_sorted[0]
    print(f"Best MSE: {best['mse']:.2f} (Store: {best['store']}, Product: {best['product']})")
    print(f"Worst MSE: {worst['mse']:.2f} (Store: {worst['store']}, Product: {worst['product']})")

# Show comparison and error metrics for first few combinations (highest MSE)
for result in comparison_results_sorted[:5]:
    print(f"Store: {result['store']}, Product: {result['product']}")
    print("Actual:", result['actual'])
    print("Predicted:", result['predicted'])
    print(f"MSE: {result['mse']:.2f}, MAE: {result['mae']:.2f}, RMSE: {result['rmse']:.2f}")
    print()
# Out:
# Best MSE: 119.26 (Store: 3, Product: 5)
# Worst MSE: 8352.34 (Store: 1, Product: 1)
# Store: 1, Product: 1
# Actual: [698 690 693 722 731 720 709 689 709 699 742 721 726 724 706 705 692 726
#  741 732 708 700 710 707 724 745 745 727 709 713 703 726 725 732 721 705
#  708 719 742 730 728 711 701 700 724 734 760 766 740 709 695 726 737 749
#  738 749 727 707 731 756 742 754 761 722 709 750 761 754 767 755 716 729
#  743 767 758 792 757 752 739 746 778 779 771 771 760 735 775 778 805 786
#  769 764 763 788 792 800 780 778 762 780 777 791 795 802 783 764 774 772
#  782 801 798 798 790 797 779 812 810 815 804 790 799 799 814 811 820 805
#  798 792 830 849 839 832 814 797 812 798 820 851 840 823 801 816 834 839
#  865 844 818 816 812 834 832 852 847 839 829 835 834 838 842 853 836 827
#  828 831 841 856 853 838 829 831 808 859 857 859 839 842 847 848 851 861
#  856 830 830 835 857 848 864 861 852 824 834 840 844 869 854 855 823 826
#  850 847 868 873 842 832 809 840 854 855 863 831 841 797 816 846 861 842
#  843 842 835 841 839 843 861 841 837 814 826 824 866 829 835 831 814 813
#  841 852 847 847 824 822 817 840 840 835 841 802 821 815 826 844 843 828
#  800 800 813 799 845 842 810 790 791 793 809 833 826 795 793 789 813 815
#  821 812 799 772 780 800 798 810 817 805 787 796 781 797 794 805 802 781
#  792 774 806 809 798 792 783 767 772 777 800 798 783 775 767 763 779 776
#  808 787 754 773 785 777 790 803 753 763 773 773 787 794 800 757 756 764
#  758 777 795 759 769 752 741 761 771 773 789 757 757 750 747 781 783 789
#  773 740 756 763 773 794 793 772 746 729 753 772 774 782 773 761 738 745
#  777 777 780 760 745]
# Predicted: 2019-01-01    708.674013
# 2019-01-02    709.438334
# 2019-01-03    709.787308
# 2019-01-04    709.946642
# 2019-01-05    710.019391
#                  ...
# 2019-12-27    710.080515
# 2019-12-28    710.080515
# 2019-12-29    710.080515
# 2019-12-30    710.080515
# 2019-12-31    710.080515
# Freq: D, Name: predicted_mean, Length: 365, dtype: float64
# MSE: 8352.34, MAE: 80.61, RMSE: 91.39
#
# Store: 5, Product: 6
# Actual: [ 953  953  973  961  952  972  960  979  970  988  988  979  994  967
#   996  987  974  977 1011  987  968  994 1016 1014  990  993 1007 1023
#  1007 1018 1018  998 1001 1029 1022 1008 1005 1023 1020 1031 1025 1036
#  1025 1043 1022 1038 1032 1037 1026 1016 1050 1040 1054 1055 1036 1042
#  1046 1049 1033 1042 1066 1075 1043 1046 1055 1061 1045 1050 1047 1045
#  1062 1061 1055 1075 1078 1058 1047 1078 1050 1069 1068 1066 1083 1051
#  1057 1083 1083 1065 1067 1068 1055 1055 1062 1048 1086 1085 1070 1061
#  1058 1051 1072 1061 1057 1051 1064 1062 1084 1058 1065 1067 1067 1065
#  1042 1044 1055 1056 1065 1059 1063 1031 1063 1053 1073 1060 1065 1027
#  1044 1040 1027 1041 1058 1041 1038 1048 1039 1052 1037 1043 1036 1046
#  1019 1022 1024 1029 1024 1007 1028 1021  999 1027 1012 1001 1039 1012
#  1012 1006 1028 1003  993 1005  996  982  987  989 1005  996  980  980
#   969  996  994  986  979  976  999  960  972  987  966  950  959  953
#   946  968  956  947  955  957  961  953  963  953  954  946  942  949
#   917  911  944  927  948  931  941  941  920  925  912  926  892  927
#   930  920  909  906  905  903  916  902  915  894  894  907  906  887
#   898  890  908  904  885  908  888  872  894  885  892  895  877  881
#   883  885  885  889  866  859  866  881  876  872  872  865  875  861
#   879  863  872  876  867  886  863  859  867  880  877  887  866  870
#   849  839  874  869  849  865  857  848  863  840  871  870  871  868
#   850  866  855  869  881  887  907  880  893  873  892  877  854  866
#   883  872  874  892  870  885  879  874  906  885  883  891  862  887
#   890  891  906  892  882  898  905  885  891  909  886  891  907  922
#   903  889  898  929  920  930  908  903  905  923  919  928  929  946
#   923  913  913  950  955  941  941  952  923  940  934  940  945  948
#   942  950  963  947  956  955  957  964  974  959  972  969  975  969
#   971]
# Predicted: 2019-01-01    954.619279
# 2019-01-02    954.997422
# 2019-01-03    954.975012
# 2019-01-04    954.976340
# 2019-01-05    954.976261
#                  ...
# 2019-12-27    954.976266
# 2019-12-28    954.976266
# 2019-12-29    954.976266
# 2019-12-30    954.976266
# 2019-12-31    954.976266
# Freq: D, Name: predicted_mean, Length: 365, dtype: float64
# MSE: 5061.11, MAE: 62.30, RMSE: 71.14
#
# Store: 0, Product: 4
# Actual: [ 998 1012  989  953  981  975  977 1004 1008  988  975  976  959  967
#   994 1008 1000  958  957  960  976  994  999  994  957  953  962  982
#  1008 1001  982  951  955  935  964  983  993  991  942  950  944  975
#   980  985  957  937  923  944  959  965  971  954  941  926  955  945
#   979  978  965  950  927  930  954  946  970  957  935  913  932  921
#   964  965  957  942  920  926  938  956  959  958  926  914  897  947
#   944  951  930  916  895  906  921  952  939  925  893  896  884  926
#   932  934  937  910  905  914  903  899  936  900  899  908  893  901
#   926  929  922  885  870  896  904  928  906  919  891  870  878  880
#   917  894  907  887  843  873  891  909  907  880  869  881  865  884
#   885  902  877  878  867  868  874  903  892  892  874  846  843  854
#   882  884  896  864  854  845  878  895  884  893  861  846  851  878
#   882  909  880  861  870  858  856  891  888  864  861  846  861  864
#   893  887  898  872  872  860  892  886  898  883  855  860  839  861
#   903  889  889  886  845  858  882  874  902  902  865  849  856  884
#   886  911  861  870  856  867  873  912  900  893  874  864  859  890
#   907  916  888  891  872  873  895  903  921  887  879  866  882  908
#   915  901  902  897  863  897  874  893  940  909  886  883  891  899
#   933  938  924  885  899  906  908  938  944  949  916  886  896  927
#   950  950  934  928  924  909  923  933  963  943  935  898  899  950
#   954  951  947  944  931  911  942  959  971  969  941  938  933  950
#   977  959  966  930  930  929  956 1002  987  958  955  942  946  980
#   989  992  969  969  939  966  977  984  994  989  962  958  936  977
#   982  994  988  970  962  952  977 1000 1005 1015  964  948  967  958
#   996 1013  993  974  970  963  976  997  998  993  983  980  975  995
#  1023 1013 1008  978  973  977 1014 1018 1025  990  992  970  991  997
#  1004]
# Predicted: 2019-01-01    979.197684
# 2019-01-02    979.176711
# 2019-01-03    979.178936
# 2019-01-04    979.178700
# 2019-01-05    979.178725
#                  ...
# 2019-12-27    979.178723
# 2019-12-28    979.178723
# 2019-12-29    979.178723
# 2019-12-30    979.178723
# 2019-12-31    979.178723
# Freq: D, Name: predicted_mean, Length: 365, dtype: float64
# MSE: 4709.54, MAE: 56.74, RMSE: 68.63
#
# Store: 0, Product: 1
# Actual: [712 721 719 722 681 704 688 699 726 704 694 694 702 709 696 711 696 693
#  686 710 696 692 708 709 708 689 688 707 691 712 703 698 694 680 696 688
#  711 690 702 688 676 681 687 692 697 665 672 679 702 690 692 672 681 667
#  686 705 694 678 691 669 670 676 692 685 691 681 680 668 682 661 672 669
#  669 659 670 659 670 670 668 672 651 649 644 659 670 683 658 676 654 660
#  662 671 685 676 645 646 655 645 665 661 647 654 655 637 667 659 656 656
#  620 649 644 642 655 656 637 642 620 655 641 644 634 640 635 635 617 634
#  650 647 641 639 624 621 628 646 648 635 619 622 634 637 625 638 630 621
#  594 611 640 631 634 627 626 623 624 635 633 647 640 619 602 604 611 628
#  614 623 628 618 611 618 613 628 623 600 612 613 614 614 620 613 600 621
#  625 613 626 606 610 611 598 626 620 621 603 609 608 604 598 610 617 602
#  621 608 604 600 613 618 609 622 598 619 602 606 599 612 635 617 603 609
#  620 617 630 612 601 609 608 600 625 621 632 605 608 599 622 622 624 616
#  606 614 610 620 625 630 623 614 599 613 635 632 622 625 628 615 619 615
#  639 637 619 614 608 632 610 617 621 610 602 603 619 653 624 639 636 619
#  618 621 631 639 619 644 650 621 630 635 632 648 642 644 628 658 634 637
#  642 637 633 629 628 625 643 639 637 621 632 636 631 645 642 640 629 626
#  621 642 631 647 652 630 647 630 638 646 652 648 648 631 656 639 628 652
#  648 673 631 647 648 637 647 637 649 610 628 637 636 650 642 654 625 643
#  639 640 653 646 657 625 643 652 660 665 643 633 644 632 626 667 645 660
#  635 645 632 654 657]
# Predicted: 2019-01-01    705.695164
# 2019-01-02    705.655381
# 2019-01-03    705.650190
# 2019-01-04    705.649512
# 2019-01-05    705.649424
#                  ...
# 2019-12-27    705.649410
# 2019-12-28    705.649410
# 2019-12-29    705.649410
# 2019-12-30    705.649410
# 2019-12-31    705.649410
# Freq: D, Name: predicted_mean, Length: 365, dtype: float64
# MSE: 4707.90, MAE: 62.34, RMSE: 68.61
#
# Store: 5, Product: 3
# Actual: [ 950  957  981  972  970  993  970  960  952  982  990  987  980 1002
#   978  972  993 1006 1012  996  995  999  987 1009  984 1006 1024 1014
#  1008 1005 1032 1012 1021 1018 1020  995 1008 1023 1020 1027 1022 1003
#  1009 1015 1012 1006 1043 1054 1024 1027 1012 1034 1028 1031 1031 1023
#  1026 1012 1008 1033 1036 1048 1037 1036 1024 1029 1050 1055 1046 1043
#  1040 1023 1024 1042 1043 1057 1045 1042 1028 1037 1047 1053 1062 1032
#  1041 1037 1049 1056 1049 1052 1039 1013 1047 1041 1048 1055 1038 1045
#  1046 1029 1050 1043 1054 1044 1044 1034 1016 1053 1022 1051 1033 1044
#  1016 1024 1034 1027 1039 1029 1020 1034 1018 1022 1037 1050 1037 1024
#  1017 1000 1029 1028 1008 1013 1018 1000 1018 1020 1013 1026 1010 1005
#  1011  999  998 1005 1004  999 1002 1000 1002 1001  995 1015  997  987
#   993  997 1007 1005  989  977  985  977  990  980  994  995  984  979
#   970  967  980  967  983  992  956  971  957  963  960  950  978  967
#   956  945  959  948  962  956  961  925  930  928  950  959  949  930
#   947  933  936  947  946  929  948  908  900  935  924  917  922  920
#   912  925  914  898  939  910  904  908  906  907  907  925  918  901
#   888  901  909  896  906  904  892  885  887  881  903  884  883  893
#   897  889  878  875  886  890  877  875  883  888  900  899  895  886
#   877  869  876  880  876  890  872  883  871  872  861  880  871  875
#   877  872  865  884  889  874  876  862  854  869  891  892  856  889
#   859  853  867  882  894  875  860  859  865  875  872  881  884  883
#   866  891  877  903  881  886  888  878  868  890  905  881  894  882
#   904  883  875  893  894  891  889  878  887  893  891  902  880  878
#   897  876  909  902  913  897  890  886  895  919  908  905  912  888
#   906  905  933  905  911  925  920  910  904  893  920  941  940  914
#   920  894  916  927  938  939  917  913  927  933  944  941  946  914
#   939]
# Predicted: 2019-01-01    961.382580
# 2019-01-02    961.596924
# 2019-01-03    961.630154
# 2019-01-04    961.635306
# 2019-01-05    961.636104
#                  ...
# 2019-12-27    961.636251
# 2019-12-28    961.636251
# 2019-12-29    961.636251
# 2019-12-30    961.636251
# 2019-12-31    961.636251
# Freq: D, Name: predicted_mean, Length: 365, dtype: float64
# MSE: 3885.25, MAE: 56.65, RMSE: 62.33
